# %%
import random

def gen(a,b):
    for i in range(ord(a),ord(b)):
        x = random.randint(ord(a),i+1)
        print (x) 
     

#This code will take two alphabetical values and the code must have in alphabetical order .
#It would display the choice of two random numbers between first character and the follow up with the secomd character

x = input("enter a chracter:")
y = input("enter another:")    
z = gen(x,y)
print(z)
# Out:
# 97
# 97
# 98
# 99
# 101
# 98
# 102
# 105
# 104
# 107
# 107
# 104
# 100
# 106
# 104
# 110
# 99
# 111
# 110
# 117
# 114
# 119
# 120
# 108
# 122
# None

# %%
import random

def one(n):
    for i in range(1,n):
        x = random.randint(97,122) #ASCII for a-z
        print(chr(x),end ="")

#main
n = int(input("enter any number greater than 1:"))
y = one(n)
# Out:
# ikciaayqlhlyremqvfnedzrhyqurntqpvfewyxppryjxeptvfjagkotretrvgmdhhuuwkhooprqemqmixvggdwhfkkvvvclebxxsklandaznvztgbrktizfyasqfkyyzhzehjxemqouhakhvgdedpaqvck

# %%
import random
for i in range(1,8):
    x=random.randint(1,i+1)
    print(x)
# Out:
# 2
# 3
# 2
# 4
# 6
# 2
# 2
