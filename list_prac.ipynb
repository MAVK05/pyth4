# %%
import random
l = [1,4,89,23,90,80]#shuffling of a list
random.shuffle(l)
print(l)
# Out:
# [4, 1, 23, 90, 80, 89]

# %%
#index operator
list = [1,2,3,4,5]
alist = [9,8,7,6,5,4]
list2 = list[4]+alist[4]
print(list2)
# Out:
# 10

# %%
a = int('11',2)
print(a)
# Out:
# 3

# %%
list1 = [2,3,12,90]
list2 = [78,12,11,23,78]
list3 = list1 + list2
print(list3)
print(list3*3)
list3 += [7,8]
print(list3)
# Out:
# [2, 3, 12, 90, 78, 12, 11, 23, 78]
# [2, 3, 12, 90, 78, 12, 11, 23, 78, 2, 3, 12, 90, 78, 12, 11, 23, 78, 2, 3, 12, 90, 78, 12, 11, 23, 78]
# [2, 3, 12, 90, 78, 12, 11, 23, 78, 7, 8]

# %%
l = [56,89,5,80,80]
print(3 in l)
80 in l
# Out:
# False
# True

# %%
#lexicographical ordering i.e also known as the dictionary ordering
#here the ascii code comparison of the strings is done
#shorter one gets the priority 

print("app"<"apple")
print("hello"<"cat")
l1 = [67,89,25,89,23,54,11,0,76]
print(sorted(l1))
#but the problem arises if the numbers are to be treated as the strings
l2 = ["23","56","11","1","90"]
print(sorted(l2)) #here sorted as string
print(type(l1))
print(type(l2))
# Out:
# True
# False
# [0, 11, 23, 25, 54, 67, 76, 89, 89]
# ['1', '11', '23', '56', '90']
# <class 'list'>
# <class 'list'>

# %%
list = [4,89,9,56]
list[3]
list[-2]
# Out:
# 9
